# %%
# %reload_ext autoreload
# %autoreload 2
import os, sys
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="4"  # specify which GPU(s) to be used
import torch
import torch.nn as nn
import numpy as np
from tqdm import tqdm_notebook as tqdm
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd
import time
import matplotlib.pyplot as plt
import pickle as pkl

# %%
fold = 1
portion = 60
mode = f"curriculum_easy_{portion}idx"
percent = 0.1
df = pd.read_csv(f"./Train_Data_{mode}_{fold}.csv")
total_train_num = len(df.loc[df["split"] != fold])
exclude_num = int(percent * total_train_num * percent)
include_auto_num = int(percent * total_train_num + exclude_num)
include_expert_num = int(percent * total_train_num)
print(f"exclude {exclude_num} images, add {include_auto_num} images automatically, require {include_expert_num} to be annotated.")
# Out:
# exclude 74 images, add 822 images automatically, require 748 to be annotated.

# %%
idx_in_pool = set(np.load(f"../Idxs/{mode}_{fold}.npy"))

# %%
len(idx_in_pool), total_train_num
# Out:
# (7405, 7486)

# %% [markdown]
# ### Exclude noisy samples that are hard and medium examples

# %%
ranked_stats = np.load(f"../Step4_Training/runs/train_ranked_sample_loss_{fold}_{mode}.npy")
df_temp = df.loc[ranked_stats[:,0].astype(int)]
df_temp.head(20)
# Out:
#                               image_id data_provider  isup_grade  \
# 7102  fc8bbe93363ee983d99c949f41ea180f    karolinska           5
# 2273  67f5929b81aef7c91f8501e93cb04193    karolinska           2
# 5620  1dfa9e0e91f817fbd98ae93fc20d6255    karolinska           5
# 8133  d34c7fe759808771f0b2dc65ad0df03c       radboud           4
# 2192  b90fb52788bc4fc6be21377c096008c3    karolinska           4
# 7155  d4dcb1cd15053d17de19d2d63ddcb173       radboud           4
# 993   7234d2bf2df91f65e94e9ecc4ec5827d       radboud           3
# 3301  fc07f0ce6d2cdff9d65591e94fc2130e    karolinska           5
# 5444  9079ffff621fc4e738b65b66587bfa47       radboud           5
# 3373  2db286ff4d3398fa6538678a6452497f    karolinska           1
# 6402  946e85479cd3ac3e73f2698c9cf01806       radboud           2
# 995   5a4ec1ea101e790664aeab41d54cbe75    karolinska           2
# 9088  e97f116751795bc832eeefae3227ba0b       radboud           2
# 7756  b66da14818c806a8913a205fab8c6037    karolinska           5
# 6871  1254b6e7bf569bb23c87369196f6e816       radboud           5
# 2011  ea295f8383b74ad29cf5ba2daea89f98    karolinska           4
# 8677  085d3e58058fa98dcbbdf64dacfe51be       radboud           3
# 426   1aaa3e8a1b4a738cb9a2d358dd45dbc5       radboud           4
# 7212  b4320e9769062a33fd948fa2593b1417       radboud           4
# 98    a71f5c9931a10907ca1b1fd09d5b0798    karolinska           2
#
#      gleason_score  tile_number  split  \
# 7102           5+4           37    0.0
# 2273           3+4           40    0.0
# 5620           5+5           58    3.0
# 8133           4+4           10    0.0
# 2192           4+4           45    0.0
# 7155           3+5           56    2.0
# 993            4+3           41    2.0
# 3301           4+5           27    3.0
# 5444           4+5           46    0.0
# 3373           3+3           55    2.0
# 6402           3+4           44    2.0
# 995            3+4           30    0.0
# 9088           3+4           17    3.0
# 7756           4+5           33    0.0
# 6871           4+5           33    0.0
# 2011           3+5           47    0.0
# 8677           4+3           44    2.0
# 426            4+4           32    3.0
# 7212           4+4           12    0.0
# 98             3+4           35    2.0
#
#                                              tile_pixel  \
# 7102  80,79,77,72,75,68,68,61,59,67,69,54,57,62,65,6...
# 2273  98,88,90,86,90,85,85,86,79,78,85,77,78,80,69,7...
# 5620  110,111,116,111,108,103,99,96,99,99,98,97,98,9...
# 8133                   111,109,89,89,86,84,75,66,71,42,
# 2192  70,73,67,74,71,70,69,70,70,71,64,69,65,64,58,6...
# 7155  110,104,98,101,89,95,86,100,89,99,92,86,81,87,...
# 993   98,102,88,84,88,97,91,72,87,91,101,92,99,88,75...
# 3301  87,82,87,74,79,74,69,80,77,71,66,60,63,54,54,5...
# 5444  106,104,86,97,105,88,91,107,100,87,93,88,82,95...
# 3373  127,122,120,117,117,112,110,112,107,112,107,10...
# 6402  121,118,110,97,112,98,92,115,103,99,97,87,97,9...
# 995   147,134,131,121,124,122,112,120,112,112,114,11...
# 9088  78,78,89,75,63,68,57,51,57,70,48,46,46,40,49,5...
# 7756  81,75,73,75,70,73,73,72,74,75,71,70,69,67,62,6...
# 6871  116,103,95,77,88,91,83,82,93,100,90,75,88,77,9...
# 2011  118,116,110,113,113,108,102,108,110,100,108,97...
# 8677  124,114,105,87,101,107,94,100,104,90,84,102,77...
# 426   90,98,79,65,87,69,86,86,86,63,67,55,51,65,54,5...
# 7212               47,55,42,43,45,41,47,46,26,44,60,40,
# 98    117,110,108,90,96,97,93,89,86,87,86,90,82,83,8...
#
#                                          tile_blueratio  image_idx  \
# 7102  28,28,27,27,27,25,26,26,25,26,25,25,25,25,25,2...       7102
# 2273  34,32,29,32,30,29,28,32,30,30,28,28,27,31,29,2...       2273
# 5620  47,50,44,36,37,34,33,41,32,32,39,33,33,32,33,3...       5620
# 8133                     46,38,41,38,32,32,28,29,28,23,       8133
# 2192  27,26,26,26,26,25,26,26,26,26,25,26,25,25,24,2...       2192
# 7155  41,38,35,37,34,36,34,37,35,34,39,33,31,32,33,3...       7155
# 993   35,42,33,31,32,37,30,30,37,36,36,35,35,31,29,3...        993
# 3301  30,33,30,28,29,28,27,28,27,26,25,25,25,24,24,2...       3301
# 5444  42,38,34,33,33,33,33,38,39,33,33,34,30,32,37,3...       5444
# 3373  46,47,42,45,43,42,40,37,38,38,40,38,38,42,35,3...       3373
# 6402  46,45,40,31,35,38,34,39,39,38,37,38,37,34,33,3...       6402
# 995   42,45,44,45,44,42,42,37,34,36,44,41,41,42,40,4...        995
# 9088  30,29,30,29,25,25,23,24,23,26,24,22,22,21,22,2...       9088
# 7756  30,27,27,27,27,27,27,27,28,27,26,26,26,26,26,2...       7756
# 6871  43,44,35,33,33,32,32,32,37,34,34,33,32,29,32,3...       6871
# 2011  48,46,49,44,40,47,44,45,45,40,39,42,38,38,42,3...       2011
# 8677  48,43,38,37,42,42,35,39,37,37,34,40,38,35,34,2...       8677
# 426   35,36,28,27,33,27,31,29,29,27,30,25,28,27,24,2...        426
# 7212               22,23,22,21,22,21,22,21,19,22,23,21,       7212
# 98    43,38,44,40,36,34,36,38,38,38,37,37,38,35,36,3...         98
#
#       k_means_grp  curicullum_cluster_grp
# 7102            5                       1
# 2273            1                       0
# 5620            5                       0
# 8133            1                       0
# 2192            1                       0
# 7155            1                       0
# 993            10                       1
# 3301            5                       1
# 5444           10                       2
# 3373            6                       0
# 6402            4                       1
# 995             1                       0
# 9088            8                       2
# 7756            1                       0
# 6871            5                       1
# 2011            1                       1
# 8677           10                       1
# 426            10                       0
# 7212            1                       1
# 98             11                       0

# %%
df_temp_ = df_temp.loc[df["curicullum_cluster_grp"] != 3]
exclude_id = df_temp_.image_idx.tolist()
if len(exclude_id) > exclude_num:
    print("exclude example is enough!")
else:
    print("hard example is not enough to exclude!")
# Out:
# exclude example is enough!

# %% [markdown]
# ### Include samples from: 1 automatic prediction; 2 expert annotation

# %%
ranked_stats = np.load(f"../Step4_Training/runs/unlabel_ranked_sample_entropy_{fold}_{mode}.npy")
df_temp = df.loc[ranked_stats[:,0].astype(int)]
df_temp.head(20)
# Out:
#                               image_id data_provider  isup_grade  \
# 5534  e4858d718f97a3ff5dab42484f5b1bd7       radboud           5
# 900   1e1862f8927813cacf7391cc55848ba4       radboud           5
# 8892  50416fa0e1642f024c10c25c90ec5bff    karolinska           4
# 1311  934f3bcb20dfdd3e184f53df0383b9e0       radboud           4
# 7818  82e968eacc5a5abf71fa6cefb97c0910    karolinska           5
# 813   9aea86aa9b34cebb8bbc0db42d6c7559    karolinska           5
# 4260  083ab9e2c95fb0ea2b999c592fb41653       radboud           2
# 6430  86ff52ec50c7e0b2b3549e9bb1524770    karolinska           4
# 3252  cc66d0b4ad6375c6bed929d10c98a716    karolinska           4
# 4774  0c7d6e0e07621b5582117e9977327b4c       radboud           3
# 1026  07a7ef0ba3bb0d6564a73f4f3e1c2293    karolinska           4
# 9890  24cbc57ba378971a02cf24479cd7933d       radboud           5
# 577   491f1c9e8e27e4660ed001d968610ed6       radboud           3
# 5956  fd05529859cf5ee53ab967a009dc7c06       radboud           3
# 5605  ef8cb1391e62cb6721eddf6e3495087d       radboud           3
# 7617  33453ab3633e39269f3368e83acb993b    karolinska           4
# 3945  a87dead1b6909eb28749a88d7610c5ff    karolinska           3
# 5986  e2319f2602a2099c2e64ce1c15ffef10    karolinska           3
# 4349  fd8c1f420a7c1c28bab654d0d8d3a6ba       radboud           2
# 6963  cfbe34e8826d4e2bb02061d9ef056e83    karolinska           3
#
#      gleason_score  tile_number  split  \
# 5534           4+5           15    0.0
# 900            5+4           34    0.0
# 8892           4+4           44    0.0
# 1311           3+5           16    2.0
# 7818           5+5           23    0.0
# 813            5+5           45    0.0
# 4260           3+4           43    3.0
# 6430           3+5           40    0.0
# 3252           4+4           37    0.0
# 4774           4+3           22    2.0
# 1026           4+4           29    2.0
# 9890           4+5           21    3.0
# 577            4+3           39    2.0
# 5956           4+3            9    0.0
# 5605           4+3           58    2.0
# 7617           4+4           32    2.0
# 3945           4+3           19    0.0
# 5986           4+3           38    3.0
# 4349           3+4           52    2.0
# 6963           4+3           36    3.0
#
#                                              tile_pixel  \
# 5534      73,64,81,78,60,69,61,72,65,77,68,35,39,45,28,
# 900   66,86,63,65,91,79,80,86,78,76,67,80,57,56,58,5...
# 8892  76,69,77,64,66,66,70,66,73,70,72,64,58,67,68,6...
# 1311  101,92,93,102,107,110,99,105,95,103,91,102,88,...
# 7818  88,82,81,78,78,77,75,76,69,70,73,61,66,68,66,6...
# 813   106,106,105,105,105,100,97,99,96,96,90,94,95,9...
# 4260  111,107,114,103,101,100,110,99,107,113,105,108...
# 6430  106,103,99,92,93,92,92,90,85,83,87,84,81,81,77...
# 3252  102,99,95,94,91,93,83,84,81,80,79,82,76,76,75,...
# 4774  71,77,68,73,64,74,70,68,64,62,70,56,59,55,59,4...
# 1026  105,90,89,87,81,88,86,80,73,76,81,74,74,73,72,...
# 9890  121,127,118,113,107,91,103,100,61,68,75,71,62,...
# 577   105,81,93,83,95,84,76,85,84,86,79,80,74,81,78,...
# 5956                     110,96,96,100,96,98,84,78,103,
# 5605  107,101,95,93,88,92,88,85,83,78,82,76,74,67,76...
# 7617  64,65,65,62,65,62,57,63,56,52,59,59,53,59,51,5...
# 3945  79,74,78,75,74,76,73,73,69,62,65,66,66,59,53,5...
# 5986  102,96,96,96,91,96,93,94,93,93,89,86,73,68,73,...
# 4349  144,108,129,128,90,126,94,108,109,123,116,91,1...
# 6963  130,127,126,125,122,122,122,115,115,115,115,11...
#
#                                          tile_blueratio  image_idx  \
# 5534      33,31,32,30,28,29,25,28,29,28,27,21,22,22,20,       5534
# 900   33,34,33,30,33,32,32,32,30,29,26,30,25,24,26,2...        900
# 8892  26,26,28,25,25,26,25,25,27,26,26,25,24,25,25,2...       8892
# 1311   47,42,41,42,44,46,37,38,36,37,34,38,34,33,31,25,       1311
# 7818  31,28,30,29,26,30,29,27,26,29,25,24,25,25,26,2...       7818
# 813   37,39,38,37,35,34,33,34,32,32,32,31,32,32,33,3...        813
# 4260  44,34,39,40,37,37,41,31,41,41,42,37,35,32,37,3...       4260
# 6430  32,34,33,33,32,33,32,33,33,30,32,31,31,31,28,3...       6430
# 3252  38,35,33,33,32,33,32,31,31,30,30,30,29,27,28,2...       3252
# 4774  29,30,27,29,27,28,28,27,26,26,28,25,26,24,25,2...       4774
# 1026  36,32,32,30,31,28,28,28,27,26,28,26,26,26,26,2...       1026
# 9890  50,49,46,44,39,33,38,39,36,31,34,31,30,30,30,2...       9890
# 577   38,30,37,30,37,35,29,32,34,34,29,28,33,30,32,3...        577
# 5956                        44,37,37,36,36,34,31,31,35,       5956
# 5605  35,36,33,31,30,31,31,29,28,27,29,27,29,28,27,3...       5605
# 7617  27,26,27,26,25,24,25,25,25,24,24,24,24,25,24,2...       7617
# 3945  28,27,27,26,26,27,25,25,25,24,25,24,24,24,23,2...       3945
# 5986  41,36,34,33,39,33,34,33,36,34,34,34,32,30,30,2...       5986
# 4349  74,70,68,78,61,60,69,56,56,46,44,42,42,44,41,4...       4349
# 6963  47,46,43,44,41,39,39,46,38,43,34,35,43,33,38,4...       6963
#
#       k_means_grp  curicullum_cluster_grp
# 5534            2                       2
# 900             5                       1
# 8892            1                       0
# 1311            1                       0
# 7818            5                       1
# 813             1                       1
# 4260            4                       1
# 6430            1                       0
# 3252            1                       0
# 4774            1                       1
# 1026           10                       0
# 9890            1                       1
# 577             1                       1
# 5956            4                       1
# 5605            1                       0
# 7617            1                       1
# 3945            1                       0
# 5986            1                       0
# 4349            4                       1
# 6963            1                       0

# %%
df_temp_ = df_temp.loc[df["curicullum_cluster_grp"] != 2] ## no hard group
include_id_auto = df_temp_.image_idx.tolist()[::-1]
if len(include_id_auto) > include_auto_num:
    print("include auto easy example is enough!")
else:
    print("include auto easy is not enough!")
# Out:
# include auto easy is not enough!

# %%
include_id_expert = df_temp.image_idx.tolist()[:include_expert_num]

# %%
len(include_id_expert), len(include_id_auto)
# Out:
# (81, 57)

# %% [markdown]
# ### Save the selection ID

# %%
selected_idx = {"exclude_noisy":exclude_id[:exclude_num], 
               "include_auto": include_id_auto[:include_auto_num],
               "include_expert": include_id_expert}
np.save(f"selected_idx_{mode}_{fold}.npy", selected_idx)
