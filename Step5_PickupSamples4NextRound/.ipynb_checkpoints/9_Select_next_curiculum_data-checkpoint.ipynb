# %%
# %reload_ext autoreload
# %autoreload 2
import os, sys
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="5"  # specify which GPU(s) to be used
import torch
import torch.nn as nn
import numpy as np
from tqdm import tqdm_notebook as tqdm
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import seaborn as sns
import pandas as pd
import time
import matplotlib.pyplot as plt
import pickle as pkl

# %%
fold = 0
portion = 10
mode = f"curriculum_easy_{portion}idx"
percent = 0.1
df = pd.read_csv(f"./Train_Data_{mode}_{fold}.csv")
total_train_num = len(df.loc[df["split"] != fold])
exclude_num = int(percent * total_train_num * percent)
include_auto_num = int(percent * total_train_num + exclude_num)
include_expert_num = int(percent * total_train_num)

# %%
idx_in_pool = set(np.load(f"../Idxs/{mode}_{fold}.npy"))

# %% [markdown]
# ### Exclude noisy samples that are hard and medium examples

# %%
ranked_stats = np.load(f"../Step4_Training/runs/train_ranked_sample_loss_{fold}_{mode}.npy")
df_temp = df.loc[ranked_stats[:,0].astype(int)]
df_temp.head(20)
# Out:
#                               image_id data_provider  isup_grade  \
# 9888  eb1f095d4c42b43b2263dc50203fb26c    karolinska           4
# 993   7234d2bf2df91f65e94e9ecc4ec5827d       radboud           3
# 7155  d4dcb1cd15053d17de19d2d63ddcb173       radboud           4
# 594   5e79a8e720579946198a701deeed3a4a       radboud           5
# 5825  ff339e5fa7be6af83c1b43796092398f    karolinska           4
# 7237  f56bfb09d7abb23b45fac3113fee9c9b    karolinska           4
# 5888  b0b0bb292409f1613351c5a4c2f6a25a       radboud           4
# 6056  42cb31b9fc4dca6da8112c72600ce8e3       radboud           3
# 4792  05f79307ac65a11d52caeada92e68949       radboud           4
# 3870  86e1e1f8d6a8d630b1577b3a5f3d65a3    karolinska           2
# 8027  0da878110769739fb9439908862be9ba    karolinska           2
# 7969  8bf80024b1a7f12ce52136af81a930df       radboud           3
# 5501  155867d947fe378bcce54cc1adf8acba    karolinska           2
# 3728  dac43b12a554b5d13719d80d348e962f    karolinska           4
# 2737  6ca9348a09b4bceff7a738ae8b37f369       radboud           5
# 9639  2902a2f38703f59632892819a1c72377       radboud           3
# 2029  9f2739434a4444b74f5cbe8888a77ea2    karolinska           3
# 37    861349e0094f9af0986ca3ed1ea7ba6b    karolinska           5
# 118   c699f572c40dbee492ca9ac0c1a0d9f7    karolinska           2
# 8567  da959308ba225828ad7bfca0ce00f42a    karolinska           1
#
#      gleason_score  tile_number  split  \
# 9888           4+4           51    1.0
# 993            4+3           41    2.0
# 7155           3+5           56    2.0
# 594            5+4           34    3.0
# 5825           4+4           30    2.0
# 7237           4+4           31    1.0
# 5888           3+5           26    3.0
# 6056           4+3           48    2.0
# 4792           4+4           10    2.0
# 3870           3+4           29    3.0
# 8027           3+4           46    1.0
# 7969           4+3           19    3.0
# 5501           3+4           30    1.0
# 3728           4+4           37    3.0
# 2737           5+4           30    3.0
# 9639           4+3           15    3.0
# 2029           4+3           44    1.0
# 37             4+5           43    2.0
# 118            3+4           31    2.0
# 8567           3+3           39    2.0
#
#                                              tile_pixel  \
# 9888  80,77,72,77,75,73,68,72,77,68,68,63,65,67,65,6...
# 993   98,102,88,84,88,97,91,72,87,91,101,92,99,88,75...
# 6056            5                       0
# 4792            2                       1
# 3870           11                       0
# 8027            7                       2
# 7969           11                       0
# 5501            5                       0
# 3728            5                       0
# 2737           10                       2
# 9639           11                       1
# 2029            5                       0
# 37              2                       2
# 118             1                       2
# 8567           11                       0

# %%
df_temp_ = df_temp.loc[df["curicullum_cluster_grp"] != 3]
exclude_id = df_temp_.image_idx.tolist()
if len(exclude_id) > exclude_num:
    print("exclude example is enough!")
else:
    print("hard example is not enough to exclude!")
# Out:
# exclude example is enough!

# %% [markdown]
# ### Include samples from: 1 automatic prediction; 2 expert annotation

# %%
ranked_stats = np.load(f"../Step4_Training/runs/unlabel_ranked_sample_entropy_{fold}_{mode}.npy")
df_temp = df.loc[ranked_stats[:,0].astype(int)]
df_temp.head(20)
# Out:
#                               image_id data_provider  isup_grade  \
# 7434  60502735df319ec33f862579fb6563d5    karolinska           0
# 3270  b28f0f94ebc50f79d1b03cf0c0baa335       radboud           0
# 8672  f187290ba0d588d11f47467ec93ce202       radboud           5
# 6981  886682be4f834c17abfcbd5137374279       radboud           0
# 2345  dec45a32f96c496a9141d49617286870       radboud           0
# 6292  917a41204bed06f0a0313e6bbe0e2743    karolinska           3
# 4436  4da79675b490fd611075cd6b84b83adb       radboud           0
# 8725  29d80dc50d0b6ba0c43087089514c688    karolinska           0
# 2722  750cf428f4f94ee2c4142320505b57e2       radboud           3
# 6836  de06480e9ad90fd6fbb3b2496eb6d35b       radboud           0
# 7222  5cd64763e1df1acf97df32f5e310bcd6       radboud           3
# 5494  2fd7cbd01f3cecb64e915a0a62121cda       radboud           0
# 9103  68d28aa1831633cd996a227062f03bee       radboud           1
# 9467  29a1168a223e589bb808ac09c36c1d56    karolinska           0
# 4888  3205cf61128c41e20cf2c12c3c89b2a5    karolinska           0
# 6038  ca0aebc5cee6bc82416face9227ea416    karolinska           0
# 7862  c8c898c68a6cbe37412468d561e3a7b4    karolinska           0
# 3010  e92dfc70e301a7e97540ac17cb56cdae       radboud           0
# 6889  fab7172275db33a4e186e6deeb435a7b       radboud           5
# 7341  2ae016457e8ff8e21723a91b57a96d7d       radboud           4
#
#      gleason_score  tile_number  split  \
# 7434           0+0            1    1.0
# 3270      negative            4    3.0
# 8672           4+5           11    2.0
# 6981      negative            3    3.0
# 2345      negative            6    1.0
# 6292           4+3           28    2.0
# 4436      negative           10    2.0
# 8725           0+0           26    1.0
# 2722           4+3           21    2.0
# 6836      negative           21    1.0
# 7222           4+3           28    2.0
# 5494      negative           13    3.0
# 9103           3+3            5    2.0
# 9467           0+0           15    2.0
# 4888           0+0           28    1.0
# 6038           0+0            8    3.0
# 7862           0+0            8    1.0
# 3010      negative           23    2.0
# 6889           5+5           27    1.0
# 7341           3+5            2    2.0
#
#                                              tile_pixel  \
# 7434                                                62,
# 3270                                       82,78,47,66,
# 8672             110,113,107,104,96,103,97,84,75,71,55,
# 6981                                          79,84,65,
# 2345                                 69,52,61,51,57,24,
# 6292  116,114,103,107,105,90,102,97,80,89,87,71,72,5...
# 4436                     73,66,75,53,53,50,51,32,30,30,
# 8725  108,108,103,105,104,106,94,98,83,78,81,78,85,7...
# 2722  89,73,73,79,70,80,59,73,67,62,85,78,51,43,46,5...
# 6836  79,88,85,57,66,80,67,71,68,66,74,65,58,57,55,5...
# 7222  150,143,147,143,138,128,120,100,127,128,119,11...
# 5494         113,87,101,101,94,82,82,82,71,67,74,40,32,
# 9103                                    73,75,93,65,50,
# 9467    120,101,87,90,86,81,78,63,73,63,52,51,45,42,26,
# 4888  82,75,78,67,76,62,71,59,54,59,57,60,59,60,53,6...
# 6038                           71,53,51,42,31,28,29,21,
# 7862                           70,61,67,68,54,39,31,24,
# 3010  96,84,88,93,85,90,81,78,66,81,55,69,55,51,40,5...
# 6889  102,109,97,99,102,105,87,78,85,91,83,87,79,72,...
# 7341                                             60,41,
#
#                                          tile_blueratio  image_idx  \
# 7434                                                24,       7434
# 3270                                       31,32,24,26,       3270
# 8672                  43,48,41,40,36,39,36,31,29,27,25,       8672
# 6981                                          33,31,27,       6981
# 2345                                 25,23,25,22,24,19,       2345
# 6292  40,39,39,38,37,37,36,34,33,33,31,32,30,31,25,2...       6292
# 4436                     27,26,28,26,23,24,24,21,20,20,       4436
# 8725  33,34,33,34,33,33,31,32,29,31,30,30,29,28,27,2...       8725
# 2722  33,29,29,30,30,29,26,28,27,26,30,29,24,25,26,2...       2722
# 6836  28,32,31,25,25,28,26,26,27,25,27,25,24,24,23,2...       6836
# 7222  67,53,51,50,52,52,53,55,53,46,45,41,36,43,43,4...       7222
# 5494            33,28,31,31,30,28,27,27,26,26,26,21,20,       5494
# 9103                                    28,29,30,28,24,       9103
# 9467      69,45,31,33,29,30,29,31,27,25,24,24,23,22,20,       9467
# 4888  30,28,28,26,27,25,26,24,25,25,24,25,25,24,24,2...       4888
# 6038                           26,23,23,22,20,19,20,19,       6038
# 7862                           25,25,25,25,23,21,20,19,       7862
# 3010  36,35,33,38,32,32,31,30,27,29,25,26,23,23,22,2...       3010
# 6889  34,40,34,33,36,37,35,30,33,31,34,32,28,30,29,2...       6889
# 7341                                             23,21,       7341
#
#       k_means_grp  curicullum_cluster_grp
# 7434            1                       2
# 3270            7                       2
# 8672            2                       1
# 6981            1                       2
# 2345           11                       2
# 6292            5                       1
# 4436            5                       1
# 8725           10                       2
# 2722           11                       0
# 6836            5                       1
# 7222            7                       0
# 5494            7                       2
# 9103            5                       1
# 9467           11                       0
# 4888           11                       2
# 6038            1                       1
# 7862           11                       1
# 3010            2                       2
# 6889            7                       0
# 7341           11                       2

# %%
df_temp_ = df_temp.loc[df["curicullum_cluster_grp"] != 2] ## no hard group
include_id_auto = df_temp_.image_idx.tolist()[::-1]
if len(include_id_auto) > include_auto_num:
    print("include auto easy example is enough!")
else:
    print("include auto easy is not enough!")
# Out:
# include auto easy example is enough!

# %%
include_id_expert = df_temp_.image_idx.tolist()[:include_expert_num]

# %% [markdown]
# ### Save the selection ID

# %%
selected_idx = {"exclude_noisy":exclude_id[:exclude_num], 
               "include_auto": include_id_auto[:include_auto_num],
               "include_expert": include_id_expert}
np.save(f"selected_idx_{mode}_{fold}.npy", selected_idx)
